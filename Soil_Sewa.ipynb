# %%
import pandas as pd
import numpy as np

# %%
soil_df=pd.read_csv('/content/soil_dataset (3).csv')

# %%
soil_df
# Out:
#           soil_type                                            texture  \
# 0             Sandy  [0.0690594456016664, 0.07525058306183126, 0.06...
# 1             Sandy  [0.09858350678774706, 0.0930022656523421, 0.08...
# 2             Sandy  [0.04414942883606051, 0.061284347020685394, 0....
# 3             Sandy  [0.10238507661558961, 0.09692871419053964, 0.0...
# 4             Sandy  [0.0795664284036377, 0.08286184100137589, 0.07...
# ...             ...                                                ...
# 2620  Alluvial_Soil  [0.143024, 0.11792533333333333, 0.04968, 0.044...
# 2621  Alluvial_Soil  [0.14062257849031395, 0.11630728122912491, 0.0...
# 2622  Alluvial_Soil  [0.10594375, 0.10480625, 0.06998125, 0.0777812...
# 2623  Alluvial_Soil  [0.08279128959276018, 0.09663461538461539, 0.0...
# 2624  Alluvial_Soil  [0.04112558198062162, 0.06359527704374816, 0.0...
#
#      organic_matter           moisture  \
# 0            Medium  Moderate Moisture
# ...

# %%
import matplotlib.pyplot as plt

# %%
soil_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2625 entries, 0 to 2624
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   soil_type       2625 non-null   object
#  1   texture         2625 non-null   object
#  2   organic_matter  2625 non-null   object
#  3   moisture        2625 non-null   object
#  4   pixels          2625 non-null   object
# dtypes: object(5)
# memory usage: 102.7+ KB

# %%
soil_df.isnull().sum()
# Out:
# soil_type         0
# texture           0
# organic_matter    0
# moisture          0
# pixels            0
# dtype: int64

# %%
soil_df['pixels']
# Out:
# 0       [33, 69, 101, 0, 15, 52, 139, 180, 215, 117, 1...
# 1       [36, 54, 83, 60, 78, 109, 50, 67, 100, 34, 48,...
# 2       [90, 159, 194, 113, 167, 217, 88, 147, 193, 11...
# 3       [14, 44, 114, 98, 132, 187, 82, 97, 143, 135, ...
# 4       [57, 83, 97, 73, 104, 125, 81, 118, 145, 67, 1...
#                               ...
# 2620    [112, 133, 164, 109, 130, 161, 103, 124, 155, ...
# 2621    [104, 125, 156, 107, 128, 159, 104, 125, 156, ...
# 2622    [75, 123, 171, 83, 131, 179, 88, 136, 184, 85,...
# 2623    [85, 125, 150, 38, 78, 102, 97, 139, 164, 81, ...
# 2624    [224, 239, 241, 224, 239, 241, 222, 237, 238, ...
# Name: pixels, Length: 2625, dtype: object

# %%
print(type(soil_df['pixels'][0]))
# Out:
# <class 'str'>

# %%
import ast


# Convert string to a Python list and then to a NumPy array
soil_df['pixels'] = soil_df['pixels'].apply(lambda x: np.array(ast.literal_eval(x), dtype=int))

# %%
print(type(soil_df['pixels'][0]))
# Out:
# <class 'numpy.ndarray'>

# %%
print(type(soil_df['pixels'][0][0]))
# Out:
# <class 'numpy.int64'>

# %%
print(soil_df['pixels'][0])
# Out:
# [ 33  69 101 ...  67 109 128]

# %%
soil_df['pixels']=soil_df['pixels'].apply(lambda x: x.reshape(96,96,3))
